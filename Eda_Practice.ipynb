# %% [markdown]
# <a href="https://colab.research.google.com/github/GovindSantoshS/Software_Engineering_lab/blob/Collab-Sheets/Eda_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data=np.array([10,20,30,40,50])
def min_max_normalization(data):
    min_val=np.min(data)
    max_val=np.max(data)
    normalized_data=(data-min_val)/(max_val-min_val)
    return normalized_data
normalize_data=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8cf3d813d1ec> in <cell line: 8>()
#       6     normalized_data=(data-min_val)/(max_val-min_val)
#       7     return normalized_data
# ----> 8 normalize_
#
# NameError: name 'normalize_' is not defined

# %%
iris.plot(kind='scatter',x•'sepla_length'
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris=sns.load_dataset("iris")

# %%
import csv
with open('IRIS.csv') as File:
    IRIS = csv.reader(File)

# %%
sns.set_style("whitegrid")
sns.pairplot(iris, hue=("species"), height = 3)

# %%
import pandas as pd
iris_setosa=iris.loc[iris["species"]=="setosa"]
iris_versi

# %%
import numpy as np

# %%
iris_setosa = iris.loc[iris["species"] == "setosa"];
iris_virginica = iris.loc[iris["species"] == "virginica"];
iris_versicolor = iris.loc[iris["species"] == "versicolor"];

plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa["petal_length"]), "o", label="setosa")
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica["petal_length"]), "o", label="virginica")
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor["petal_length"]), "o", label="versicolor")
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
iris_setosa = iris.loc[iris["species"] == "setosa"];
iris_virginica = iris.loc[iris["species"] == "virginica"];
iris_versicolor = iris.loc[iris["species"] == "versicolor"];
print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']),'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']),'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']),'o')
plt.show()
# Out:
# 0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# 11    1.6
# 12    1.4
# 13    1.1
# 14    1.2
# 15    1.5
# 16    1.3
# 17    1.4
# 18    1.7
# 19    1.5
# 20    1.7
# 21    1.5
# 22    1.0
# 23    1.7
# 24    1.9
# 25    1.6
# 26    1.6
# 27    1.5
# 28    1.4
# 29    1.6
# 30    1.6
# 31    1.5
# 32    1.5
# 33    1.4
# 34    1.5
# 35    1.2
# 36    1.3
# 37    1.4
# 38    1.3
# 39    1.5
# 40    1.3
# 41    1.3
# 42    1.3
# 43    1.6
# 44    1.9
# 45    1.4
# 46    1.6
# 47    1.4
# 48    1.5
# 49    1.4
# Name: petal_length, dtype: float64

# %%
import numpy as np
iris_setosa=iris.loc[iris["species"]]
